# %%
# 1. Imports
import sqlite3
import pandas as pd
from sklearn.preprocessing import StandardScaler

# 2. Conectar ao banco e carregar a tabela de features
conn = sqlite3.connect("../data/database.sqlite")

# Lê toda a tabela match_features criada
df = pd.read_sql_query("SELECT * FROM match_features;", conn)

print("Primeiras linhas da match_features:")
print(df.head())
print("Formato do df (linhas, colunas):", df.shape)

# 3. Definir colunas de features (HOME/AWAY separados) e de contexto
feature_cols = [
    "shots_home", "shots_away",
    "shots_on_home", "shots_on_away",
    "possession_home", "possession_away",
    "corners_home", "corners_away",
    "crosses_home", "crosses_away",
    "fouls_home", "fouls_away",
    "yellows_home", "yellows_away",
    "reds_home", "reds_away",
]

# Colunas de contexto (não entram no vetor, mas estão aqui e podem auxiliar na posterior análise)
context_cols = [
    "match_id",
    "league_id",
    "season",
    "home_team_api_id",
    "away_team_api_id",
    "home_team_goal",
    "away_team_goal",
    "goal_diff",
    "result_label",
]

# 4. Trata valores ausentes (NaN) nas features
# Alguns jogos podem não ter posse ou certos eventos registrados, logo preenchem NaN com 0.0 nas features.
df[feature_cols] = df[feature_cols].fillna(0.0)

print("\nVerificando se ainda há NaN nas features:")
print(df[feature_cols].isna().sum())  # ideal é imprimir tudo 0

# 5. Padronizar as features por liga (z-score)
# Cria um novo DataFrame df_scaled, onde cada feature é padronizada
# DENTRO de cada liga. Assim, por exemplo, shots_home_z indica
# quantos desvios-padrão acima/abaixo da média da liga aquele valor está.
dfs_scaled = []

for league_id, df_league in df.groupby("league_id"):
    print(f"\nPadronizando liga {league_id} com {len(df_league)} partidas...")
    
    scaler = StandardScaler()
    X = df_league[feature_cols].values  # Matriz de features dessa liga
    
    # fit_transform: calcula média/desvio na liga e aplica o z-score
    X_scaled = scaler.fit_transform(X)
    
    # Copia o df dessa liga e adiciona colunas *_z com os valores padronizados
    df_league_scaled = df_league.copy()
    for i, col in enumerate(feature_cols):
        df_league_scaled[col + "_z"] = X_scaled[:, i]
    
    dfs_scaled.append(df_league_scaled)

# Junta todas as ligas de volta num único DataFrame
df_scaled = pd.concat(dfs_scaled, ignore_index=True)

# Lista das colunas padronizadas (que vão compor o vetor)
z_feature_cols = [col + "_z" for col in feature_cols]

print("\nPrimeiras linhas com features padronizadas (z-score):")
print(df_scaled[context_cols + z_feature_cols].head())

# 6. Monta a matriz de vetores de atributos (X_vectors)
# Aqui, cada linha de X_vectors é um VETOR de atributos de uma partida,
# com as estatísticas separadas de mandante e visitante, padronizadas por liga.
X_vectors = df_scaled[z_feature_cols].values

print("\nFormato de X_vectors (n_partidas, n_features):", X_vectors.shape)

print("\nPrimeiro vetor de atributos (array):")
print(X_vectors[0])

print("\nPrimeiro vetor de atributos com nomes das features:")
print(df_scaled[z_feature_cols].iloc[0])

# Fecha a conexão com o banco
conn.close()
# Out:
# Primeiras linhas da match_features:
#    match_id  league_id     season  home_team_api_id  away_team_api_id  \
# 0      1729       1729  2008/2009             10260             10261
# 1      1730       1729  2008/2009              9825              8659
# 2      1731       1729  2008/2009              8472              8650
# 3      1732       1729  2008/2009              8654              8528
# 4      1733       1729  2008/2009             10252              8456
#
#    home_team_goal  away_team_goal  goal_diff  result_label  shots_home  ...  \
# 0               1               1          0             0          21  ...
# 1               1               0          1             1          25  ...
# 2               0               1         -1            -1           7  ...
# 3               2               1          1             1          12  ...
# 4               4               2          2             1           9  ...
#
#    yellows_home  yellows_away  reds_home  reds_away  cards_index_home  \
# 0             3             0          0          0                 3
# 1             0             0          0          0                 0
# 2             0             2          0          0                 0
# 3             2             1          0          0                 2
# 4             0             1          0          0                 0
#
#    cards_index_away  cards_index_diff  possession_home  possession_away  \
# 0                 0                 3            54.75            45.25
# 1                 0                 0            64.25            35.75
# 2                 2                -2            45.50            54.50
# 3                 1                 1            49.75            50.25
# 4                 1                -1            51.50            48.50
#
#    possession_diff
# 0              9.5
# 1             28.5
# 2             -9.0
# 3             -0.5
# 4              3.0
#
# [5 rows x 34 columns]
# Formato do df (linhas, colunas): (18455, 34)
#
# Verificando se ainda há NaN nas features:
# shots_home         0
# shots_away         0
# shots_on_home      0
# shots_on_away      0
# possession_home    0
# possession_away    0
# corners_home       0
# corners_away       0
# crosses_home       0
# crosses_away       0
# fouls_home         0
# fouls_away         0
# yellows_home       0
# yellows_away       0
# reds_home          0
# reds_away          0
# dtype: int64
#
# Padronizando liga 1729 com 3040 partidas...
#
# Padronizando liga 4769 com 3040 partidas...
#
# Padronizando liga 7809 com 2448 partidas...
#
# Padronizando liga 10257 com 3017 partidas...
#
# Padronizando liga 13274 com 2448 partidas...
#
# Padronizando liga 21518 com 3040 partidas...
#
# Padronizando liga 24558 com 1422 partidas...
#
# Primeiras linhas com features padronizadas (z-score):
#    match_id  league_id     season  home_team_api_id  away_team_api_id  \
# 0      1729       1729  2008/2009             10260             10261
# 1      1730       1729  2008/2009              9825              8659
# 2      1731       1729  2008/2009              8472              8650
# 3      1732       1729  2008/2009              8654              8528
# 4      1733       1729  2008/2009             10252              8456
#
#    home_team_goal  away_team_goal  goal_diff  result_label  shots_home_z  ...  \
# 0               1               1          0             0      1.435451  ...
# 1               1               0          1             1      2.180154  ...
# 2               0               1         -1            -1     -1.171008  ...
# 3               2               1          1             1     -0.240130  ...
# 4               4               2          2             1     -0.798657  ...
#
#    corners_home_z  corners_away_z  crosses_home_z  crosses_away_z  \
# 0       -0.040241        0.437276        0.352869       -0.983353
# 1        0.277505        0.069349        0.009415       -1.254524
# 2       -1.628969        1.173128       -0.677494        0.372504
# 3       -0.040241        1.908981       -0.677494        1.457189
# 4        0.277505        1.173128       -0.563009       -0.034253
#
#    fouls_home_z  fouls_away_z  yellows_home_z  yellows_away_z  reds_home_z  \
# 0      1.497584     -0.107877        1.301452       -1.383897    -0.203836
# 1      0.087133     -0.650386       -1.201551       -1.383897    -0.203836
# 2      0.651313      0.163377       -1.201551        0.114339    -0.203836
# 3      0.933404      0.434632        0.467117       -0.634779    -0.203836
# 4      0.087133      0.434632       -1.201551       -0.634779    -0.203836
#
#    reds_away_z
# 0    -0.224489
# 1    -0.224489
# 2    -0.224489
# 3    -0.224489
# 4    -0.224489
#
# [5 rows x 25 columns]
#
# Formato de X_vectors (n_partidas, n_features): (18455, 16)
#
# Primeiro vetor de atributos (array):
# [ 1.43545115 -0.10833681  1.22919151 -1.45601397  0.33248617 -0.31518008
#  -0.04024082  0.43727569  0.3528691  -0.98335272  1.49758445 -0.10787714
#   1.30145151 -1.38389684 -0.20383605 -0.22448945]
#
# Primeiro vetor de atributos com nomes das features:
# shots_home_z         1.435451
# shots_away_z        -0.108337
# shots_on_home_z      1.229192
# shots_on_away_z     -1.456014
# possession_home_z    0.332486
# possession_away_z   -0.315180
# corners_home_z      -0.040241
# corners_away_z       0.437276
# crosses_home_z       0.352869
# crosses_away_z      -0.983353
# fouls_home_z         1.497584
# fouls_away_z        -0.107877
# yellows_home_z       1.301452
# yellows_away_z      -1.383897
# reds_home_z         -0.203836
# reds_away_z         -0.224489
# Name: 0, dtype: float64
